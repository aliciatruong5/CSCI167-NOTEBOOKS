# %% [markdown]
# <a href="https://colab.research.google.com/github/aliciatruong5/CSCI167-NOTEBOOKS/blob/main/Notebooks/Chap08/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-1tahq7o0
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-1tahq7o0
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.10.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=8301eaa5cbf2fd420a749d3a071d4631f74fced2a3e2b19201b2c6617bc8e123
#   Stored in directory: /tmp/pip-ephem-wheel-cache-94nbvjg1/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# ✓ TODO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
#
# *   I think that the training error will become zero at 160 hidden variables.
#
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
#
# *   I expect the first minima of the double descent curve to appear at 25 hidden variables.
#
# 3. At what capacity do you expect the maximum of the double descent curve to appear?
#
# *   I expect the maximum of the double descent curve to appear at 200 hidden variables.

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.302633, train error 90.28,  test loss 2.303332, test error 90.93
# Epoch   100, train loss 1.896192, train error 72.55,  test loss 1.762670, test error 69.62
# Epoch   200, train loss 1.859096, train error 70.50,  test loss 1.695872, test error 68.28
# Epoch   300, train loss 1.854787, train error 71.10,  test loss 1.696715, test error 67.65
# Epoch   400, train loss 1.855088, train error 70.55,  test loss 1.699932, test error 68.38
# Epoch   500, train loss 1.858926, train error 70.78,  test loss 1.704421, test error 67.90
# Epoch   600, train loss 1.850256, train error 70.38,  test loss 1.689385, test error 68.55
# Epoch   700, train loss 1.861927, train error 71.40,  test loss 1.710989, test error 68.30
# Epoch   800, train loss 1.849204, train error 70.75,  test loss 1.687908, test error 67.62
# Epoch   900, train loss 1.851925, train error 70.03,  test loss 1.691922, test error 67.45
# Training model with   4 hidden variables
# Epoch     0, train loss 2.256859, train error 85.68,  test loss 2.244994, test error 85.85
# Epoch   100, train loss 1.766666, train error 64.85,  test loss 1.571882, test error 61.92
# Epoch   200, train loss 1.750560, train error 63.70,  test loss 1.532850, test error 59.95
# Epoch   300, train loss 1.731259, train error 62.22,  test loss 1.523455, test error 59.33
# Epoch   400, train loss 1.734521, train error 62.08,  test loss 1.538781, test error 59.12
# Epoch   500, train loss 1.733265, train error 63.12,  test loss 1.527925, test error 59.83
# Epoch   600, train loss 1.734228, train error 62.70,  test loss 1.533697, test error 58.90
# Epoch   700, train loss 1.738775, train error 62.50,  test loss 1.528431, test error 59.83
# Epoch   800, train loss 1.732815, train error 61.55,  test loss 1.532373, test error 58.35
# Epoch   900, train loss 1.733487, train error 62.47,  test loss 1.527083, test error 59.42
# Training model with   6 hidden variables
# Epoch     0, train loss 2.208292, train error 82.88,  test loss 2.185724, test error 81.35
# Epoch   100, train loss 1.694471, train error 61.22,  test loss 1.531719, test error 59.60
# Epoch   200, train loss 1.651040, train error 59.10,  test loss 1.499122, test error 58.55
# Epoch   300, train loss 1.628930, train error 57.70,  test loss 1.492615, test error 57.38
# Epoch   400, train loss 1.628524, train error 57.72,  test loss 1.487145, test error 57.85
# Epoch   500, train loss 1.619830, train error 57.97,  test loss 1.490197, test error 57.40
# Epoch   600, train loss 1.610338, train error 57.50,  test loss 1.491506, test error 57.08
# Epoch   700, train loss 1.607132, train error 57.20,  test loss 1.483948, test error 56.62
# Epoch   800, train loss 1.607236, train error 57.45,  test loss 1.484102, test error 56.78
# Epoch   900, train loss 1.603830, train error 57.28,  test loss 1.488604, test error 56.45
# Training model with   8 hidden variables
# Epoch     0, train loss 2.211579, train error 82.30,  test loss 2.182902, test error 81.22
# Epoch   100, train loss 1.609375, train error 55.33,  test loss 1.430840, test error 54.95
# Epoch   200, train loss 1.528678, train error 52.12,  test loss 1.377619, test error 51.95
# Epoch   300, train loss 1.503998, train error 51.50,  test loss 1.381944, test error 52.25
# Epoch   400, train loss 1.491895, train error 51.42,  test loss 1.379683, test error 52.50
# Epoch   500, train loss 1.493137, train error 52.20,  test loss 1.368479, test error 51.97
# Epoch   600, train loss 1.491045, train error 51.72,  test loss 1.377251, test error 52.10
# Epoch   700, train loss 1.484013, train error 51.40,  test loss 1.362621, test error 51.62
# Epoch   800, train loss 1.484625, train error 51.70,  test loss 1.364993, test error 51.22
# Epoch   900, train loss 1.485313, train error 51.50,  test loss 1.368011, test error 51.28
# Training model with  10 hidden variables
# Epoch     0, train loss 2.288352, train error 87.95,  test loss 2.292412, test error 87.97
# Epoch   100, train loss 1.500691, train error 51.12,  test loss 1.314058, test error 48.78
# Epoch   200, train loss 1.440875, train error 49.47,  test loss 1.280788, test error 47.25
# Epoch   300, train loss 1.417826, train error 47.75,  test loss 1.284702, test error 47.17
# Epoch   400, train loss 1.404418, train error 47.20,  test loss 1.302768, test error 47.40
# Epoch   500, train loss 1.393459, train error 47.08,  test loss 1.313220, test error 47.47
# Epoch   600, train loss 1.380902, train error 47.45,  test loss 1.310266, test error 47.78
# Epoch   700, train loss 1.374245, train error 46.58,  test loss 1.313335, test error 47.53
# Epoch   800, train loss 1.372040, train error 46.85,  test loss 1.330809, test error 48.42
# Epoch   900, train loss 1.367764, train error 46.10,  test loss 1.336244, test error 47.97
# Training model with  14 hidden variables
# Epoch     0, train loss 2.246778, train error 84.40,  test loss 2.240985, test error 84.40
# Epoch   100, train loss 1.409050, train error 47.03,  test loss 1.325271, test error 50.00
# Epoch   200, train loss 1.340696, train error 45.12,  test loss 1.307897, test error 48.60
# Epoch   300, train loss 1.306117, train error 43.78,  test loss 1.331228, test error 49.10
# Epoch   400, train loss 1.294369, train error 43.25,  test loss 1.342465, test error 49.25
# Epoch   500, train loss 1.274735, train error 42.90,  test loss 1.349276, test error 48.78
# Epoch   600, train loss 1.259461, train error 42.03,  test loss 1.366752, test error 48.33
# Epoch   700, train loss 1.259400, train error 42.10,  test loss 1.385380, test error 49.17
# Epoch   800, train loss 1.246438, train error 41.42,  test loss 1.417872, test error 48.83
# Epoch   900, train loss 1.238786, train error 41.22,  test loss 1.442257, test error 49.88
# Training model with  18 hidden variables
# Epoch     0, train loss 2.195512, train error 81.45,  test loss 2.177567, test error 80.85
# Epoch   100, train loss 1.352504, train error 45.17,  test loss 1.340350, test error 50.00
# Epoch   200, train loss 1.253191, train error 41.75,  test loss 1.341193, test error 49.08
# Epoch   300, train loss 1.198153, train error 40.72,  test loss 1.360555, test error 49.22
# Epoch   400, train loss 1.166304, train error 39.45,  test loss 1.383815, test error 49.67
# Epoch   500, train loss 1.153705, train error 38.55,  test loss 1.407348, test error 49.97
# Epoch   600, train loss 1.137891, train error 38.53,  test loss 1.431144, test error 49.97
# Epoch   700, train loss 1.126107, train error 38.25,  test loss 1.455087, test error 49.78
# Epoch   800, train loss 1.112041, train error 37.53,  test loss 1.464022, test error 49.28
# Epoch   900, train loss 1.114263, train error 38.38,  test loss 1.502067, test error 50.58
# Training model with  22 hidden variables
# Epoch     0, train loss 2.228779, train error 84.00,  test loss 2.210712, test error 84.18
# Epoch   100, train loss 1.315102, train error 43.70,  test loss 1.348350, test error 50.92
# Epoch   200, train loss 1.148409, train error 37.97,  test loss 1.362716, test error 49.05
# Epoch   300, train loss 1.085522, train error 35.93,  test loss 1.464795, test error 49.90
# Epoch   400, train loss 1.062871, train error 35.75,  test loss 1.547624, test error 52.00
# Epoch   500, train loss 1.016787, train error 34.25,  test loss 1.582066, test error 51.88
# Epoch   600, train loss 1.013469, train error 34.25,  test loss 1.631451, test error 52.28
# Epoch   700, train loss 0.979871, train error 32.93,  test loss 1.676435, test error 52.75
# Epoch   800, train loss 0.978843, train error 33.75,  test loss 1.724344, test error 52.78
# Epoch   900, train loss 0.971351, train error 32.72,  test loss 1.764316, test error 52.97
# Training model with  26 hidden variables
# Epoch     0, train loss 2.216959, train error 81.53,  test loss 2.191243, test error 80.80
# Epoch   100, train loss 1.211842, train error 39.67,  test loss 1.328059, test error 49.47
# Epoch   200, train loss 1.066008, train error 36.03,  test loss 1.409507, test error 49.53
# Epoch   300, train loss 0.978028, train error 31.93,  test loss 1.480215, test error 49.53
# Epoch   400, train loss 0.944520, train error 32.30,  test loss 1.582813, test error 51.50
# Epoch   500, train loss 0.914123, train error 30.85,  test loss 1.646459, test error 51.50
# Epoch   600, train loss 0.890739, train error 30.82,  test loss 1.735584, test error 51.90
# Epoch   700, train loss 0.857832, train error 29.38,  test loss 1.818919, test error 52.67
# Epoch   800, train loss 0.859139, train error 29.97,  test loss 1.888213, test error 52.25
# Epoch   900, train loss 0.851146, train error 30.45,  test loss 1.948275, test error 52.45
# Training model with  30 hidden variables
# Epoch     0, train loss 2.204432, train error 80.97,  test loss 2.172119, test error 79.70
# Epoch   100, train loss 1.091374, train error 35.07,  test loss 1.293189, test error 46.70
# Epoch   200, train loss 0.935374, train error 31.10,  test loss 1.489085, test error 49.17
# Epoch   300, train loss 0.831556, train error 27.35,  test loss 1.686918, test error 51.40
# Epoch   400, train loss 0.795967, train error 26.40,  test loss 1.850402, test error 51.78
# Epoch   500, train loss 0.744481, train error 25.00,  test loss 2.004796, test error 52.20
# Epoch   600, train loss 0.703906, train error 23.12,  test loss 2.099298, test error 52.38
# Epoch   700, train loss 0.699041, train error 23.50,  test loss 2.237376, test error 52.38
# Epoch   800, train loss 0.681778, train error 22.70,  test loss 2.334213, test error 52.20
# Epoch   900, train loss 0.665707, train error 22.78,  test loss 2.521101, test error 53.38
# Training model with  35 hidden variables
# Epoch     0, train loss 2.057776, train error 77.55,  test loss 2.011152, test error 76.40
# Epoch   100, train loss 0.968816, train error 30.93,  test loss 1.388001, test error 49.40
# Epoch   200, train loss 0.756675, train error 24.75,  test loss 1.730718, test error 52.15
# Epoch   300, train loss 0.659618, train error 22.28,  test loss 2.096154, test error 53.60
# Epoch   400, train loss 0.599869, train error 20.10,  test loss 2.465990, test error 54.85
# Epoch   500, train loss 0.539283, train error 18.15,  test loss 2.874138, test error 55.88
# Epoch   600, train loss 0.495820, train error 17.00,  test loss 3.192896, test error 56.85
# Epoch   700, train loss 0.456923, train error 15.82,  test loss 3.455523, test error 56.92
# Epoch   800, train loss 0.456679, train error 15.30,  test loss 3.685202, test error 56.78
# Epoch   900, train loss 0.492486, train error 16.85,  test loss 3.874051, test error 56.20
# Training model with  40 hidden variables
# Epoch     0, train loss 2.071885, train error 77.35,  test loss 2.031264, test error 77.35
# Epoch   100, train loss 0.940790, train error 30.90,  test loss 1.461014, test error 51.15
# Epoch   200, train loss 0.669717, train error 22.20,  test loss 1.961973, test error 53.17
# Epoch   300, train loss 0.516035, train error 16.85,  test loss 2.474735, test error 53.85
# Epoch   400, train loss 0.420872, train error 14.05,  test loss 3.116151, test error 56.47
# Epoch   500, train loss 0.376106, train error 12.82,  test loss 3.735085, test error 56.38
# Epoch   600, train loss 0.310704, train error 10.38,  test loss 4.312790, test error 56.62
# Epoch   700, train loss 0.330584, train error 11.55,  test loss 4.967978, test error 57.42
# Epoch   800, train loss 0.377277, train error 13.03,  test loss 5.648381, test error 58.33
# Epoch   900, train loss 0.344297, train error 11.28,  test loss 6.111781, test error 57.25
# Training model with  45 hidden variables
# Epoch     0, train loss 2.051241, train error 76.47,  test loss 1.994078, test error 75.40
# Epoch   100, train loss 0.794129, train error 26.28,  test loss 1.488395, test error 49.72
# Epoch   200, train loss 0.491417, train error 15.95,  test loss 2.205134, test error 53.67
# Epoch   300, train loss 0.330073, train error 10.95,  test loss 3.199309, test error 53.95
# Epoch   400, train loss 0.226024, train error 7.65,  test loss 4.480365, test error 56.15
# Epoch   500, train loss 0.166487, train error 5.75,  test loss 5.657184, test error 55.38
# Epoch   600, train loss 0.122304, train error 3.53,  test loss 6.687212, test error 54.55
# Epoch   700, train loss 0.165346, train error 5.78,  test loss 7.774789, test error 55.55
# Epoch   800, train loss 0.008220, train error 0.00,  test loss 8.657642, test error 55.00
# Epoch   900, train loss 0.004898, train error 0.00,  test loss 9.191646, test error 55.33
# Training model with  50 hidden variables
# Epoch     0, train loss 2.060931, train error 78.68,  test loss 1.999223, test error 78.45
# Epoch   100, train loss 0.701253, train error 21.57,  test loss 1.515463, test error 48.92
# Epoch   200, train loss 0.350181, train error 10.47,  test loss 2.578581, test error 53.40
# Epoch   300, train loss 0.170455, train error 4.68,  test loss 4.033565, test error 53.95
# Epoch   400, train loss 0.033449, train error 0.03,  test loss 5.468894, test error 54.45
# Epoch   500, train loss 0.013779, train error 0.00,  test loss 6.426437, test error 54.38
# Epoch   600, train loss 0.008556, train error 0.00,  test loss 7.039677, test error 54.83
# Epoch   700, train loss 0.006057, train error 0.00,  test loss 7.493366, test error 54.85
# Epoch   800, train loss 0.004620, train error 0.00,  test loss 7.857217, test error 54.95
# Epoch   900, train loss 0.003717, train error 0.00,  test loss 8.163243, test error 54.85
# Training model with  55 hidden variables
# Epoch     0, train loss 2.051378, train error 76.95,  test loss 1.986662, test error 76.43
# Epoch   100, train loss 0.637255, train error 20.25,  test loss 1.631002, test error 50.38
# Epoch   200, train loss 0.223432, train error 5.43,  test loss 3.071993, test error 54.10
# Epoch   300, train loss 0.046973, train error 0.07,  test loss 4.878330, test error 54.78
# Epoch   400, train loss 0.014816, train error 0.00,  test loss 5.963108, test error 55.17
# Epoch   500, train loss 0.008550, train error 0.00,  test loss 6.590994, test error 54.92
# Epoch   600, train loss 0.005810, train error 0.00,  test loss 7.052113, test error 54.88
# Epoch   700, train loss 0.004337, train error 0.00,  test loss 7.402626, test error 54.88
# Epoch   800, train loss 0.003426, train error 0.00,  test loss 7.687159, test error 55.05
# Epoch   900, train loss 0.002810, train error 0.00,  test loss 7.931212, test error 55.28
# Training model with  60 hidden variables
# Epoch     0, train loss 2.071645, train error 77.72,  test loss 2.027828, test error 77.30
# Epoch   100, train loss 0.574867, train error 16.38,  test loss 1.686689, test error 50.38
# Epoch   200, train loss 0.166706, train error 3.25,  test loss 3.185080, test error 54.60
# Epoch   300, train loss 0.026645, train error 0.00,  test loss 4.794368, test error 56.12
# Epoch   400, train loss 0.010514, train error 0.00,  test loss 5.580303, test error 56.28
# Epoch   500, train loss 0.006468, train error 0.00,  test loss 6.077507, test error 56.22
# Epoch   600, train loss 0.004563, train error 0.00,  test loss 6.453397, test error 56.38
# Epoch   700, train loss 0.003485, train error 0.00,  test loss 6.741209, test error 56.40
# Epoch   800, train loss 0.002768, train error 0.00,  test loss 6.975468, test error 56.33
# Epoch   900, train loss 0.002298, train error 0.00,  test loss 7.177206, test error 56.38
# Training model with  70 hidden variables
# Epoch     0, train loss 2.035888, train error 76.47,  test loss 1.965091, test error 75.70
# Epoch   100, train loss 0.399579, train error 11.03,  test loss 1.916252, test error 51.90
# Epoch   200, train loss 0.035298, train error 0.00,  test loss 3.686091, test error 53.78
# Epoch   300, train loss 0.011248, train error 0.00,  test loss 4.529171, test error 54.10
# Epoch   400, train loss 0.006163, train error 0.00,  test loss 5.004640, test error 54.33
# Epoch   500, train loss 0.004163, train error 0.00,  test loss 5.330112, test error 54.58
# Epoch   600, train loss 0.003064, train error 0.00,  test loss 5.570446, test error 54.50
# Epoch   700, train loss 0.002395, train error 0.00,  test loss 5.767615, test error 54.53
# Epoch   800, train loss 0.001951, train error 0.00,  test loss 5.936060, test error 54.60
# Epoch   900, train loss 0.001637, train error 0.00,  test loss 6.078705, test error 54.60
# Training model with  80 hidden variables
# Epoch     0, train loss 2.033321, train error 75.47,  test loss 1.962832, test error 74.75
# Epoch   100, train loss 0.304611, train error 6.70,  test loss 1.941252, test error 51.03
# Epoch   200, train loss 0.023878, train error 0.00,  test loss 3.310789, test error 51.25
# Epoch   300, train loss 0.008772, train error 0.00,  test loss 3.911415, test error 51.92
# Epoch   400, train loss 0.005067, train error 0.00,  test loss 4.257559, test error 52.05
# Epoch   500, train loss 0.003469, train error 0.00,  test loss 4.500210, test error 52.05
# Epoch   600, train loss 0.002585, train error 0.00,  test loss 4.688383, test error 52.12
# Epoch   700, train loss 0.002050, train error 0.00,  test loss 4.840615, test error 52.12
# Epoch   800, train loss 0.001678, train error 0.00,  test loss 4.968895, test error 52.15
# Epoch   900, train loss 0.001417, train error 0.00,  test loss 5.077668, test error 52.12
# Training model with  90 hidden variables
# Epoch     0, train loss 2.001360, train error 74.57,  test loss 1.935116, test error 73.80
# Epoch   100, train loss 0.124972, train error 0.70,  test loss 2.268488, test error 52.70
# Epoch   200, train loss 0.014650, train error 0.00,  test loss 3.327748, test error 52.95
# Epoch   300, train loss 0.006526, train error 0.00,  test loss 3.762080, test error 52.97
# Epoch   400, train loss 0.003982, train error 0.00,  test loss 4.034894, test error 52.80
# Epoch   500, train loss 0.002805, train error 0.00,  test loss 4.231975, test error 52.83
# Epoch   600, train loss 0.002131, train error 0.00,  test loss 4.386185, test error 52.78
# Epoch   700, train loss 0.001703, train error 0.00,  test loss 4.514246, test error 52.83
# Epoch   800, train loss 0.001410, train error 0.00,  test loss 4.620273, test error 52.83
# Epoch   900, train loss 0.001197, train error 0.00,  test loss 4.713069, test error 53.00
# Training model with 100 hidden variables
# Epoch     0, train loss 1.994966, train error 73.80,  test loss 1.908728, test error 73.97
# Epoch   100, train loss 0.113887, train error 0.53,  test loss 2.238516, test error 52.25
# Epoch   200, train loss 0.012880, train error 0.00,  test loss 3.134708, test error 52.47
# Epoch   300, train loss 0.005910, train error 0.00,  test loss 3.520382, test error 52.65
# Epoch   400, train loss 0.003660, train error 0.00,  test loss 3.759305, test error 52.55
# Epoch   500, train loss 0.002591, train error 0.00,  test loss 3.930776, test error 52.42
# Epoch   600, train loss 0.001980, train error 0.00,  test loss 4.066466, test error 52.45
# Epoch   700, train loss 0.001589, train error 0.00,  test loss 4.177017, test error 52.47
# Epoch   800, train loss 0.001318, train error 0.00,  test loss 4.272858, test error 52.42
# Epoch   900, train loss 0.001121, train error 0.00,  test loss 4.354414, test error 52.55
# Training model with 120 hidden variables
# Epoch     0, train loss 1.985017, train error 74.28,  test loss 1.943210, test error 74.72
# Epoch   100, train loss 0.054842, train error 0.03,  test loss 2.230382, test error 51.00
# Epoch   200, train loss 0.009683, train error 0.00,  test loss 2.837450, test error 50.70
# Epoch   300, train loss 0.004745, train error 0.00,  test loss 3.115170, test error 50.72
# Epoch   400, train loss 0.003030, train error 0.00,  test loss 3.296070, test error 51.08
# Epoch   500, train loss 0.002181, train error 0.00,  test loss 3.427215, test error 50.90
# Epoch   600, train loss 0.001684, train error 0.00,  test loss 3.532569, test error 50.85
# Epoch   700, train loss 0.001361, train error 0.00,  test loss 3.619447, test error 50.83
# Epoch   800, train loss 0.001135, train error 0.00,  test loss 3.694334, test error 50.80
# Epoch   900, train loss 0.000970, train error 0.00,  test loss 3.758467, test error 50.85
# Training model with 140 hidden variables
# Epoch     0, train loss 1.953367, train error 71.55,  test loss 1.895319, test error 73.43
# Epoch   100, train loss 0.037235, train error 0.00,  test loss 2.119669, test error 48.33
# Epoch   200, train loss 0.008169, train error 0.00,  test loss 2.600697, test error 48.85
# Epoch   300, train loss 0.004176, train error 0.00,  test loss 2.827251, test error 48.50
# Epoch   400, train loss 0.002706, train error 0.00,  test loss 2.977301, test error 48.58
# Epoch   500, train loss 0.001966, train error 0.00,  test loss 3.086151, test error 48.62
# Epoch   600, train loss 0.001527, train error 0.00,  test loss 3.173970, test error 48.78
# Epoch   700, train loss 0.001239, train error 0.00,  test loss 3.246392, test error 48.75
# Epoch   800, train loss 0.001037, train error 0.00,  test loss 3.308367, test error 48.80
# Epoch   900, train loss 0.000888, train error 0.00,  test loss 3.362798, test error 48.70
# Training model with 160 hidden variables
# Epoch     0, train loss 1.935617, train error 71.62,  test loss 1.880417, test error 72.93
# Epoch   100, train loss 0.028510, train error 0.00,  test loss 2.094359, test error 48.50
# Epoch   200, train loss 0.007106, train error 0.00,  test loss 2.498419, test error 48.50
# Epoch   300, train loss 0.003736, train error 0.00,  test loss 2.693297, test error 48.60
# Epoch   400, train loss 0.002458, train error 0.00,  test loss 2.822544, test error 48.60
# Epoch   500, train loss 0.001800, train error 0.00,  test loss 2.919026, test error 48.42
# Epoch   600, train loss 0.001406, train error 0.00,  test loss 2.996804, test error 48.38
# Epoch   700, train loss 0.001145, train error 0.00,  test loss 3.060404, test error 48.40
# Epoch   800, train loss 0.000962, train error 0.00,  test loss 3.115737, test error 48.30
# Epoch   900, train loss 0.000826, train error 0.00,  test loss 3.163816, test error 48.33
# Training model with 180 hidden variables
# Epoch     0, train loss 1.947013, train error 71.22,  test loss 1.866153, test error 70.40
# Epoch   100, train loss 0.023631, train error 0.00,  test loss 2.055913, test error 48.03
# Epoch   200, train loss 0.006447, train error 0.00,  test loss 2.409107, test error 48.03
# Epoch   300, train loss 0.003454, train error 0.00,  test loss 2.587014, test error 48.05
# Epoch   400, train loss 0.002295, train error 0.00,  test loss 2.706886, test error 47.97
# Epoch   500, train loss 0.001690, train error 0.00,  test loss 2.796917, test error 47.85
# Epoch   600, train loss 0.001325, train error 0.00,  test loss 2.868869, test error 47.88
# Epoch   700, train loss 0.001082, train error 0.00,  test loss 2.928436, test error 47.83
# Epoch   800, train loss 0.000910, train error 0.00,  test loss 2.979877, test error 47.83
# Epoch   900, train loss 0.000783, train error 0.00,  test loss 3.024527, test error 48.00
# Training model with 200 hidden variables
# Epoch     0, train loss 1.918077, train error 70.62,  test loss 1.834855, test error 71.45
# Epoch   100, train loss 0.021922, train error 0.00,  test loss 2.001812, test error 48.42
# Epoch   200, train loss 0.006127, train error 0.00,  test loss 2.308598, test error 47.90
# Epoch   300, train loss 0.003319, train error 0.00,  test loss 2.469223, test error 47.80
# Epoch   400, train loss 0.002212, train error 0.00,  test loss 2.578004, test error 47.83
# Epoch   500, train loss 0.001632, train error 0.00,  test loss 2.659913, test error 47.80
# Epoch   600, train loss 0.001281, train error 0.00,  test loss 2.725758, test error 47.80
# Epoch   700, train loss 0.001048, train error 0.00,  test loss 2.780652, test error 47.75
# Epoch   800, train loss 0.000883, train error 0.00,  test loss 2.827494, test error 47.70
# Epoch   900, train loss 0.000760, train error 0.00,  test loss 2.868394, test error 47.72
# Training model with 250 hidden variables
# Epoch     0, train loss 1.900230, train error 69.35,  test loss 1.849065, test error 70.43
# Epoch   100, train loss 0.016962, train error 0.00,  test loss 1.913457, test error 47.47
# Epoch   200, train loss 0.005322, train error 0.00,  test loss 2.169598, test error 47.38
# Epoch   300, train loss 0.002964, train error 0.00,  test loss 2.306925, test error 47.47
# Epoch   400, train loss 0.002002, train error 0.00,  test loss 2.398892, test error 47.53
# Epoch   500, train loss 0.001490, train error 0.00,  test loss 2.469585, test error 47.53
# Epoch   600, train loss 0.001176, train error 0.00,  test loss 2.525697, test error 47.53
# Epoch   700, train loss 0.000966, train error 0.00,  test loss 2.573287, test error 47.55
# Epoch   800, train loss 0.000816, train error 0.00,  test loss 2.614068, test error 47.55
# Epoch   900, train loss 0.000704, train error 0.00,  test loss 2.650139, test error 47.45
# Training model with 300 hidden variables
# Epoch     0, train loss 1.890560, train error 69.53,  test loss 1.807798, test error 70.43
# Epoch   100, train loss 0.014218, train error 0.00,  test loss 1.838076, test error 46.05
# Epoch   200, train loss 0.004751, train error 0.00,  test loss 2.052889, test error 45.97
# Epoch   300, train loss 0.002695, train error 0.00,  test loss 2.169736, test error 45.83
# Epoch   400, train loss 0.001837, train error 0.00,  test loss 2.249850, test error 45.55
# Epoch   500, train loss 0.001375, train error 0.00,  test loss 2.310944, test error 45.45
# Epoch   600, train loss 0.001090, train error 0.00,  test loss 2.360234, test error 45.33
# Epoch   700, train loss 0.000897, train error 0.00,  test loss 2.401944, test error 45.35
# Epoch   800, train loss 0.000760, train error 0.00,  test loss 2.437778, test error 45.42
# Epoch   900, train loss 0.000657, train error 0.00,  test loss 2.468941, test error 45.38
# Training model with 400 hidden variables
# Epoch     0, train loss 1.831975, train error 65.38,  test loss 1.792062, test error 69.85
# Epoch   100, train loss 0.011462, train error 0.00,  test loss 1.779129, test error 46.53
# Epoch   200, train loss 0.004078, train error 0.00,  test loss 1.952217, test error 46.28
# Epoch   300, train loss 0.002366, train error 0.00,  test loss 2.048964, test error 46.12
# Epoch   400, train loss 0.001631, train error 0.00,  test loss 2.116728, test error 46.10
# Epoch   500, train loss 0.001230, train error 0.00,  test loss 2.169074, test error 46.05
# Epoch   600, train loss 0.000980, train error 0.00,  test loss 2.211451, test error 46.17
# Epoch   700, train loss 0.000810, train error 0.00,  test loss 2.247210, test error 46.17
# Epoch   800, train loss 0.000688, train error 0.00,  test loss 2.278011, test error 46.22
# Epoch   900, train loss 0.000596, train error 0.00,  test loss 2.305138, test error 46.28

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
