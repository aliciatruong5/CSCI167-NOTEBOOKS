# %% [markdown]
# <a href="https://colab.research.google.com/github/aliciatruong5/CSCI167-NOTEBOOKS/blob/main/Notebooks/Chap12/12_4_Decoding_Strategies.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 12.4: Decoding strategies**
#
# This practical investigates neural decoding from transformer models.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (4.57.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.20.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2025.10.5)

# %%
from transformers import GPT2LMHeadModel, GPT2Tokenizer, set_seed
import torch
import torch.nn.functional as F
import numpy as np

# %%
# Load model and tokenizer
model = GPT2LMHeadModel.from_pretrained('gpt2')
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')

# %% [markdown]
# # Decoding from GPT2
#
# This tutorial investigates how to use GPT2 (the forerunner of GPT3) to generate text.  There are a number of ways to do this that trade-off the realism of the text against the amount of variation.
#
# At every stage, GPT2 takes an input string and returns a probability for each of the possible subsequent tokens.  We can choose what to do with these probability.  We could always *greedily choose* the most likely next token, or we could draw a *sample* randomly according to the probabilities.  There are also intermediate strategies such as *top-k sampling* and *nucleus sampling*, that have some controlled randomness.
#
# We'll also investigate *beam search* -- the idea is that rather than greedily take the next best token at each stage, we maintain a set of hypotheses  (beams)as we add each subsequent token and return the most likely overall hypothesis.  This is not necessarily the same result we get from greedily choosing the next token.

# %% [markdown]
# First, let's investigate the token themselves.  The code below prints out the vocabulary size and shows 20 random tokens.

# %%
np.random.seed(1)
print("Number of tokens in dictionary = %d"%(tokenizer.vocab_size))
for i in range(20):
  index = np.random.randint(tokenizer.vocab_size)
  print("Token: %d "%(index)+tokenizer.decode(torch.tensor(index), skip_special_tokens=True))
# Out:
# Number of tokens in dictionary = 50257
# Token: 33003  Mormons
# Token: 12172  cam
# Token: 5192  trig
# Token: 32511 ojure
# Token: 50057  gist
# Token: 43723  Petition
# Token: 7813  sin
# Token: 21440  Witness
# Token: 32912  Remy
# Token: 20609 isure
# Token: 49100  creeps
# Token: 7751  fasc
# Token: 43757  Alc
# Token: 31228  messenger
# Token: 36230  SYSTEM
# Token: 32025  precipitation
# Token: 21758  cores
# Token: 45413  Forestry
# Token: 35730  guru
# Token: 8444  Disc

# %% [markdown]
# # Sampling
#
# Each time we run GPT2 it will take in a set of tokens, and return a probability over each of the possible next tokens.  The simplest thing we could do is to just draw a sample from this probability distribution each time.

# %%
def sample_next_token(input_tokens, model, tokenizer):
  # Run model to get prediction over next output
  outputs = model(input_ids = input_tokens['input_ids'], attention_mask = input_tokens['attention_mask'])
  # Find prediction
  prob_over_tokens = F.softmax(outputs.logits, dim=-1).detach().numpy()[0,-1]
  # TODO Draw a random token according to the probabilities
  # next_token should be an array with an sole integer in it (as below)
  # Use:  https://numpy.org/doc/stable/reference/random/generated/numpy.random.choice.html
  # Replace this line
  next_token = np.random.choice(len(prob_over_tokens), p=prob_over_tokens)

    # Append token to sentence
  output_tokens = input_tokens
  next_token_tensor = torch.tensor([[next_token]])
  output_tokens["input_ids"] = torch.cat((output_tokens['input_ids'], next_token_tensor), dim=1)
  output_tokens['attention_mask'] = torch.cat((output_tokens['attention_mask'], torch.tensor([[1]])), dim=1)
  output_tokens['last_token_prob'] = prob_over_tokens[next_token]

  return output_tokens

# %%
# Expected output:
# "The best thing about Bath is that they don't even change or shrink anymore."

set_seed(0)
input_txt = "The best thing about Bath is"
input_tokens = tokenizer(input_txt, return_tensors='pt')
for i in range(10):
    input_tokens = sample_next_token(input_tokens, model, tokenizer)
    print(tokenizer.decode(input_tokens["input_ids"][0], skip_special_tokens=True))
# Out:
# The best thing about Bath is that
# The best thing about Bath is that they
# The best thing about Bath is that they don
# The best thing about Bath is that they don't
# The best thing about Bath is that they don't even
# The best thing about Bath is that they don't even change
# The best thing about Bath is that they don't even change or
# The best thing about Bath is that they don't even change or shrink
# The best thing about Bath is that they don't even change or shrink anymore
# The best thing about Bath is that they don't even change or shrink anymore.

# %%
# TODO Modify the code below by changing the number of tokens generated and the initial sentence
# to get a feel for how well this works.  Since I didn't reset the seed, it will give a different
# answer every time that you run it.

# TODO Experiment with changing this line:
input_txt = "The king of the pirates is"
input_tokens = tokenizer(input_txt, return_tensors='pt')
# TODO Experiment with changing this line:
for i in range(30):
    input_tokens = sample_next_token(input_tokens, model, tokenizer)
    print(tokenizer.decode(input_tokens["input_ids"][0], skip_special_tokens=True))
# Out:
# The king of the pirates is assassinated
# The king of the pirates is assassinated by
# The king of the pirates is assassinated by R
# The king of the pirates is assassinated by RPP
# The king of the pirates is assassinated by RPP.
# The king of the pirates is assassinated by RPP. After
# The king of the pirates is assassinated by RPP. After the
# The king of the pirates is assassinated by RPP. After the ensuing
# The king of the pirates is assassinated by RPP. After the ensuing wars
# The king of the pirates is assassinated by RPP. After the ensuing wars,
# The king of the pirates is assassinated by RPP. After the ensuing wars, the
# The king of the pirates is assassinated by RPP. After the ensuing wars, the pirate
# The king of the pirates is assassinated by RPP. After the ensuing wars, the pirate king
# The king of the pirates is assassinated by RPP. After the ensuing wars, the pirate king Mon
# The king of the pirates is assassinated by RPP. After the ensuing wars, the pirate king MonK
# The king of the pirates is assassinated by RPP. After the ensuing wars, the pirate king MonK gets
# The king of the pirates is assassinated by RPP. After the ensuing wars, the pirate king MonK gets removed
# The king of the pirates is assassinated by RPP. After the ensuing wars, the pirate king MonK gets removed from
# The king of the pirates is assassinated by RPP. After the ensuing wars, the pirate king MonK gets removed from parliament
# The king of the pirates is assassinated by RPP. After the ensuing wars, the pirate king MonK gets removed from parliament and
# The king of the pirates is assassinated by RPP. After the ensuing wars, the pirate king MonK gets removed from parliament and people
# The king of the pirates is assassinated by RPP. After the ensuing wars, the pirate king MonK gets removed from parliament and people start
# The king of the pirates is assassinated by RPP. After the ensuing wars, the pirate king MonK gets removed from parliament and people start attacking
# The king of the pirates is assassinated by RPP. After the ensuing wars, the pirate king MonK gets removed from parliament and people start attacking the
# The king of the pirates is assassinated by RPP. After the ensuing wars, the pirate king MonK gets removed from parliament and people start attacking the ports
# The king of the pirates is assassinated by RPP. After the ensuing wars, the pirate king MonK gets removed from parliament and people start attacking the ports of
# The king of the pirates is assassinated by RPP. After the ensuing wars, the pirate king MonK gets removed from parliament and people start attacking the ports of K
# The king of the pirates is assassinated by RPP. After the ensuing wars, the pirate king MonK gets removed from parliament and people start attacking the ports of Kans
# The king of the pirates is assassinated by RPP. After the ensuing wars, the pirate king MonK gets removed from parliament and people start attacking the ports of Kansai
# The king of the pirates is assassinated by RPP. After the ensuing wars, the pirate king MonK gets removed from parliament and people start attacking the ports of Kansai and

# %% [markdown]
# # Greedy token selection
#
# You probably (correctly) got the impression that the text from pure sampling of the probability model can be kind of random.  How about if we choose most likely token at each step?

# %%
def get_best_next_token(input_tokens, model, tokenizer):
  # Run model to get prediction over next output
  outputs = model(input_ids = input_tokens['input_ids'], attention_mask = input_tokens['attention_mask'])
  # Find prediction
  prob_over_tokens = F.softmax(outputs.logits, dim=-1).detach().numpy()[0,-1]

  # TODO -- find the token index with the maximum probability
  # It should be returns as a list (i.e., put squared brackets around it)
  # Use https://numpy.org/doc/stable/reference/generated/numpy.argmax.html
  # Replace this line
  next_token_index = np.argmax(prob_over_tokens)


  # Append token to sentence
  output_tokens = input_tokens
  output_tokens["input_ids"] = torch.cat((output_tokens['input_ids'],torch.tensor([[next_token_index]])),dim=1)
  output_tokens['attention_mask'] = torch.cat((output_tokens['attention_mask'],torch.tensor([[1]])),dim=1)
  output_tokens['last_token_prob'] = prob_over_tokens[next_token_index]
  return output_tokens

# %%
# Expected output:
# The best thing about Bath is that it's a place where you can go to
set_seed(0)
input_txt = "The best thing about Bath is"
input_tokens = tokenizer(input_txt, return_tensors='pt')
for i in range(10):
    input_tokens = get_best_next_token(input_tokens, model, tokenizer)
    print(tokenizer.decode(input_tokens["input_ids"][0], skip_special_tokens=True))
# Out:
# The best thing about Bath is that
# The best thing about Bath is that it
# The best thing about Bath is that it's
# The best thing about Bath is that it's a
# The best thing about Bath is that it's a place
# The best thing about Bath is that it's a place where
# The best thing about Bath is that it's a place where you
# The best thing about Bath is that it's a place where you can
# The best thing about Bath is that it's a place where you can go
# The best thing about Bath is that it's a place where you can go to

# %%
# TODO Modify the code below by changing the number of tokens generated and the initial sentence
# to get a feel for how well this works.

# TODO Experiment with changing this line:
input_txt = "The king of the pirates is"
input_tokens = tokenizer(input_txt, return_tensors='pt')
# TODO Experiment with changing this line:
for i in range(85):
    input_tokens = get_best_next_token(input_tokens, model, tokenizer)
    print(tokenizer.decode(input_tokens["input_ids"][0], skip_special_tokens=True))
# Out:
# The king of the pirates is a
# The king of the pirates is a man
# The king of the pirates is a man of
# The king of the pirates is a man of great
# The king of the pirates is a man of great wealth
# The king of the pirates is a man of great wealth and
# The king of the pirates is a man of great wealth and power
# The king of the pirates is a man of great wealth and power,
# The king of the pirates is a man of great wealth and power, and
# The king of the pirates is a man of great wealth and power, and he
# The king of the pirates is a man of great wealth and power, and he is
# The king of the pirates is a man of great wealth and power, and he is a
# The king of the pirates is a man of great wealth and power, and he is a man
# The king of the pirates is a man of great wealth and power, and he is a man of
# The king of the pirates is a man of great wealth and power, and he is a man of great
# The king of the pirates is a man of great wealth and power, and he is a man of great wealth
# The king of the pirates is a man of great wealth and power, and he is a man of great wealth and
# The king of the pirates is a man of great wealth and power, and he is a man of great wealth and power
# The king of the pirates is a man of great wealth and power, and he is a man of great wealth and power.
# The king of the pirates is a man of great wealth and power, and he is a man of great wealth and power. He
# The king of the pirates is a man of great wealth and power, and he is a man of great wealth and power. He is
# The king of the pirates is a man of great wealth and power, and he is a man of great wealth and power. He is a
# The king of the pirates is a man of great wealth and power, and he is a man of great wealth and power. He is a man
# The king of the pirates is a man of great wealth and power, and he is a man of great wealth and power. He is a man of
# The king of the pirates is a man of great wealth and power, and he is a man of great wealth and power. He is a man of great
# The king of the pirates is a man of great wealth and power, and he is a man of great wealth and power. He is a man of great wealth
# The king of the pirates is a man of great wealth and power, and he is a man of great wealth and power. He is a man of great wealth and
# The king of the pirates is a man of great wealth and power, and he is a man of great wealth and power. He is a man of great wealth and power
# The king of the pirates is a man of great wealth and power, and he is a man of great wealth and power. He is a man of great wealth and power.
# The king of the pirates is a man of great wealth and power, and he is a man of great wealth and power. He is a man of great wealth and power. He
# The king of the pirates is a man of great wealth and power, and he is a man of great wealth and power. He is a man of great wealth and power. He is
# The king of the pirates is a man of great wealth and power, and he is a man of great wealth and power. He is a man of great wealth and power. He is a
# The king of the pirates is a man of great wealth and power, and he is a man of great wealth and power. He is a man of great wealth and power. He is a man
# The king of the pirates is a man of great wealth and power, and he is a man of great wealth and power. He is a man of great wealth and power. He is a man of
# The king of the pirates is a man of great wealth and power, and he is a man of great wealth and power. He is a man of great wealth and power. He is a man of great
# The king of the pirates is a man of great wealth and power, and he is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth
# The king of the pirates is a man of great wealth and power, and he is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and
# The king of the pirates is a man of great wealth and power, and he is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power
# The king of the pirates is a man of great wealth and power, and he is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power.
# The king of the pirates is a man of great wealth and power, and he is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He
# The king of the pirates is a man of great wealth and power, and he is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is
# The king of the pirates is a man of great wealth and power, and he is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a
# The king of the pirates is a man of great wealth and power, and he is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man
# The king of the pirates is a man of great wealth and power, and he is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of
# The king of the pirates is a man of great wealth and power, and he is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great
# The king of the pirates is a man of great wealth and power, and he is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth
# The king of the pirates is a man of great wealth and power, and he is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and
# The king of the pirates is a man of great wealth and power, and he is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power
# The king of the pirates is a man of great wealth and power, and he is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power.
# The king of the pirates is a man of great wealth and power, and he is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He
# The king of the pirates is a man of great wealth and power, and he is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is
# The king of the pirates is a man of great wealth and power, and he is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a
# The king of the pirates is a man of great wealth and power, and he is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man
# The king of the pirates is a man of great wealth and power, and he is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of
# The king of the pirates is a man of great wealth and power, and he is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great
# The king of the pirates is a man of great wealth and power, and he is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth
# The king of the pirates is a man of great wealth and power, and he is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and
# The king of the pirates is a man of great wealth and power, and he is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power
# The king of the pirates is a man of great wealth and power, and he is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power.
# The king of the pirates is a man of great wealth and power, and he is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He
# The king of the pirates is a man of great wealth and power, and he is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is
# The king of the pirates is a man of great wealth and power, and he is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a
# The king of the pirates is a man of great wealth and power, and he is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man
# The king of the pirates is a man of great wealth and power, and he is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of
# The king of the pirates is a man of great wealth and power, and he is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great
# The king of the pirates is a man of great wealth and power, and he is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth
# The king of the pirates is a man of great wealth and power, and he is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and
# The king of the pirates is a man of great wealth and power, and he is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power
# The king of the pirates is a man of great wealth and power, and he is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power.
# The king of the pirates is a man of great wealth and power, and he is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He
# The king of the pirates is a man of great wealth and power, and he is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is
# The king of the pirates is a man of great wealth and power, and he is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a
# The king of the pirates is a man of great wealth and power, and he is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man
# The king of the pirates is a man of great wealth and power, and he is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of
# The king of the pirates is a man of great wealth and power, and he is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great
# The king of the pirates is a man of great wealth and power, and he is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth
# The king of the pirates is a man of great wealth and power, and he is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and
# The king of the pirates is a man of great wealth and power, and he is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power
# The king of the pirates is a man of great wealth and power, and he is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power.
# The king of the pirates is a man of great wealth and power, and he is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He
# The king of the pirates is a man of great wealth and power, and he is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is
# The king of the pirates is a man of great wealth and power, and he is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a
# The king of the pirates is a man of great wealth and power, and he is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man
# The king of the pirates is a man of great wealth and power, and he is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of
# The king of the pirates is a man of great wealth and power, and he is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great wealth and power. He is a man of great

# %% [markdown]
# # Top-K sampling
#
# You probably noticed that the greedy strategy produces quite realistic text, but it's kind of boring.  It produces generic answers.  Also, if this was a chatbot, then we wouldn't necessarily want it to produce the same answer to a question each time.
#
# Top-K sampling is a compromise strategy that samples randomly from the top K most probable tokens.  We could just choose them with a uniform distribution, or (as here) we could sample them according to their original probabilities.

# %%
def get_top_k_token(input_tokens, model, tokenizer, k=20):
  # Run model to get prediction over next output
  outputs = model(input_ids = input_tokens['input_ids'], attention_mask = input_tokens['attention_mask'])
  # Find prediction
  prob_over_tokens = F.softmax(outputs.logits, dim=-1).detach().numpy()[0,-1]

  # Draw a sample from the top K most likely tokens.
  # Take copy of the probabilities and sort from largest to smallest (use np.sort)
  # TODO -- replace this line
  sorted_prob_indices = np.argsort(prob_over_tokens)[::-1][:k]

  # Find the probability at the k'th position
  # TODO -- replace this line
  kth_prob_value = prob_over_tokens[sorted_prob_indices[k - 1]]

  # Set all probabilities below this value to zero
  prob_over_tokens[prob_over_tokens<kth_prob_value] = 0

  # Renormalize the probabilities so that they sum to one
  # TODO -- replace this line
  prob_over_tokens /= np.sum(prob_over_tokens)


  # Draw random token
  next_token = np.random.choice(len(prob_over_tokens), 1, replace=False, p=prob_over_tokens)

  # Append token to sentence
  output_tokens = input_tokens
  output_tokens["input_ids"] = torch.cat((output_tokens['input_ids'],torch.tensor([next_token])),dim=1)
  output_tokens['attention_mask'] = torch.cat((output_tokens['attention_mask'],torch.tensor([[1]])),dim=1)
  output_tokens['last_token_prob'] = prob_over_tokens[next_token]
  return output_tokens

# %%
# Expected output:
# The best thing about Bath is that you get to see all the beautiful faces of

set_seed(0)
input_txt = "The best thing about Bath is"
input_tokens = tokenizer(input_txt, return_tensors='pt')
for i in range(10):
    input_tokens = get_top_k_token(input_tokens, model, tokenizer, k=10)
    print(tokenizer.decode(input_tokens["input_ids"][0], skip_special_tokens=True))
# Out:
# The best thing about Bath is that
# The best thing about Bath is that you
# The best thing about Bath is that you get
# The best thing about Bath is that you get to
# The best thing about Bath is that you get to see
# The best thing about Bath is that you get to see all
# The best thing about Bath is that you get to see all the
# The best thing about Bath is that you get to see all the beautiful
# The best thing about Bath is that you get to see all the beautiful faces
# The best thing about Bath is that you get to see all the beautiful faces of

# %%
# TODO
# Experiment with different values of k
# If you set it to a lower number (say 3) the text will be less random
# If you set it to a higher number (say 5000) the text will be more random

set_seed(0)
input_txt = "The king of the pirates is"
input_tokens = tokenizer(input_txt, return_tensors='pt')
for i in range(75):
    input_tokens = get_top_k_token(input_tokens, model, tokenizer, k=10)
    print(tokenizer.decode(input_tokens["input_ids"][0], skip_special_tokens=True))
# Out:
# The king of the pirates is an
# The king of the pirates is an enemy
# The king of the pirates is an enemy of
# The king of the pirates is an enemy of the
# The king of the pirates is an enemy of the king
# The king of the pirates is an enemy of the king of
# The king of the pirates is an enemy of the king of the
# The king of the pirates is an enemy of the king of the pirates
# The king of the pirates is an enemy of the king of the pirates."
# The king of the pirates is an enemy of the king of the pirates."
#
# The king of the pirates is an enemy of the king of the pirates."
#
#
# The king of the pirates is an enemy of the king of the pirates."
#
# "
# The king of the pirates is an enemy of the king of the pirates."
#
# "And
# The king of the pirates is an enemy of the king of the pirates."
#
# "And how
# The king of the pirates is an enemy of the king of the pirates."
#
# "And how is
# The king of the pirates is an enemy of the king of the pirates."
#
# "And how is the
# The king of the pirates is an enemy of the king of the pirates."
#
# "And how is the King
# The king of the pirates is an enemy of the king of the pirates."
#
# "And how is the King of
# The king of the pirates is an enemy of the king of the pirates."
#
# "And how is the King of the
# The king of the pirates is an enemy of the king of the pirates."
#
# "And how is the King of the pirates
# The king of the pirates is an enemy of the king of the pirates."
#
# "And how is the King of the pirates supposed
# The king of the pirates is an enemy of the king of the pirates."
#
# "And how is the King of the pirates supposed to
# The king of the pirates is an enemy of the king of the pirates."
#
# "And how is the King of the pirates supposed to act
# The king of the pirates is an enemy of the king of the pirates."
#
# "And how is the King of the pirates supposed to act?"
# The king of the pirates is an enemy of the king of the pirates."
#
# "And how is the King of the pirates supposed to act?"
#
# The king of the pirates is an enemy of the king of the pirates."
#
# "And how is the King of the pirates supposed to act?"
#
#
# The king of the pirates is an enemy of the king of the pirates."
#
# "And how is the King of the pirates supposed to act?"
#
# "
# The king of the pirates is an enemy of the king of the pirates."
#
# "And how is the King of the pirates supposed to act?"
#
# "Because
# The king of the pirates is an enemy of the king of the pirates."
#
# "And how is the King of the pirates supposed to act?"
#
# "Because he
# The king of the pirates is an enemy of the king of the pirates."
#
# "And how is the King of the pirates supposed to act?"
#
# "Because he is
# The king of the pirates is an enemy of the king of the pirates."
#
# "And how is the King of the pirates supposed to act?"
#
# "Because he is a
# The king of the pirates is an enemy of the king of the pirates."
#
# "And how is the King of the pirates supposed to act?"
#
# "Because he is a pirate
# The king of the pirates is an enemy of the king of the pirates."
#
# "And how is the King of the pirates supposed to act?"
#
# "Because he is a pirate.
# The king of the pirates is an enemy of the king of the pirates."
#
# "And how is the King of the pirates supposed to act?"
#
# "Because he is a pirate. He
# The king of the pirates is an enemy of the king of the pirates."
#
# "And how is the King of the pirates supposed to act?"
#
# "Because he is a pirate. He is
# The king of the pirates is an enemy of the king of the pirates."
#
# "And how is the King of the pirates supposed to act?"
#
# "Because he is a pirate. He is the
# The king of the pirates is an enemy of the king of the pirates."
#
# "And how is the King of the pirates supposed to act?"
#
# "Because he is a pirate. He is the king
# The king of the pirates is an enemy of the king of the pirates."
#
# "And how is the King of the pirates supposed to act?"
#
# "Because he is a pirate. He is the king of
# The king of the pirates is an enemy of the king of the pirates."
#
# "And how is the King of the pirates supposed to act?"
#
# "Because he is a pirate. He is the king of pirates
# The king of the pirates is an enemy of the king of the pirates."
#
# "And how is the King of the pirates supposed to act?"
#
# "Because he is a pirate. He is the king of pirates."
# The king of the pirates is an enemy of the king of the pirates."
#
# "And how is the King of the pirates supposed to act?"
#
# "Because he is a pirate. He is the king of pirates."
#
# The king of the pirates is an enemy of the king of the pirates."
#
# "And how is the King of the pirates supposed to act?"
#
# "Because he is a pirate. He is the king of pirates."
#
#
# The king of the pirates is an enemy of the king of the pirates."
#
# "And how is the King of the pirates supposed to act?"
#
# "Because he is a pirate. He is the king of pirates."
#
# "
# The king of the pirates is an enemy of the king of the pirates."
#
# "And how is the King of the pirates supposed to act?"
#
# "Because he is a pirate. He is the king of pirates."
#
# "I
# The king of the pirates is an enemy of the king of the pirates."
#
# "And how is the King of the pirates supposed to act?"
#
# "Because he is a pirate. He is the king of pirates."
#
# "I don
# The king of the pirates is an enemy of the king of the pirates."
#
# "And how is the King of the pirates supposed to act?"
#
# "Because he is a pirate. He is the king of pirates."
#
# "I don't
# The king of the pirates is an enemy of the king of the pirates."
#
# "And how is the King of the pirates supposed to act?"
#
# "Because he is a pirate. He is the king of pirates."
#
# "I don't know
# The king of the pirates is an enemy of the king of the pirates."
#
# "And how is the King of the pirates supposed to act?"
#
# "Because he is a pirate. He is the king of pirates."
#
# "I don't know,
# The king of the pirates is an enemy of the king of the pirates."
#
# "And how is the King of the pirates supposed to act?"
#
# "Because he is a pirate. He is the king of pirates."
#
# "I don't know, but
# The king of the pirates is an enemy of the king of the pirates."
#
# "And how is the King of the pirates supposed to act?"
#
# "Because he is a pirate. He is the king of pirates."
#
# "I don't know, but that
# The king of the pirates is an enemy of the king of the pirates."
#
# "And how is the King of the pirates supposed to act?"
#
# "Because he is a pirate. He is the king of pirates."
#
# "I don't know, but that's
# The king of the pirates is an enemy of the king of the pirates."
#
# "And how is the King of the pirates supposed to act?"
#
# "Because he is a pirate. He is the king of pirates."
#
# "I don't know, but that's all
# The king of the pirates is an enemy of the king of the pirates."
#
# "And how is the King of the pirates supposed to act?"
#
# "Because he is a pirate. He is the king of pirates."
#
# "I don't know, but that's all right
# The king of the pirates is an enemy of the king of the pirates."
#
# "And how is the King of the pirates supposed to act?"
#
# "Because he is a pirate. He is the king of pirates."
#
# "I don't know, but that's all right,
# The king of the pirates is an enemy of the king of the pirates."
#
# "And how is the King of the pirates supposed to act?"
#
# "Because he is a pirate. He is the king of pirates."
#
# "I don't know, but that's all right, I
# The king of the pirates is an enemy of the king of the pirates."
#
# "And how is the King of the pirates supposed to act?"
#
# "Because he is a pirate. He is the king of pirates."
#
# "I don't know, but that's all right, I will
# The king of the pirates is an enemy of the king of the pirates."
#
# "And how is the King of the pirates supposed to act?"
#
# "Because he is a pirate. He is the king of pirates."
#
# "I don't know, but that's all right, I will tell
# The king of the pirates is an enemy of the king of the pirates."
#
# "And how is the King of the pirates supposed to act?"
#
# "Because he is a pirate. He is the king of pirates."
#
# "I don't know, but that's all right, I will tell you
# The king of the pirates is an enemy of the king of the pirates."
#
# "And how is the King of the pirates supposed to act?"
#
# "Because he is a pirate. He is the king of pirates."
#
# "I don't know, but that's all right, I will tell you this
# The king of the pirates is an enemy of the king of the pirates."
#
# "And how is the King of the pirates supposed to act?"
#
# "Because he is a pirate. He is the king of pirates."
#
# "I don't know, but that's all right, I will tell you this.
# The king of the pirates is an enemy of the king of the pirates."
#
# "And how is the King of the pirates supposed to act?"
#
# "Because he is a pirate. He is the king of pirates."
#
# "I don't know, but that's all right, I will tell you this. I
# The king of the pirates is an enemy of the king of the pirates."
#
# "And how is the King of the pirates supposed to act?"
#
# "Because he is a pirate. He is the king of pirates."
#
# "I don't know, but that's all right, I will tell you this. I have
# The king of the pirates is an enemy of the king of the pirates."
#
# "And how is the King of the pirates supposed to act?"
#
# "Because he is a pirate. He is the king of pirates."
#
# "I don't know, but that's all right, I will tell you this. I have never
# The king of the pirates is an enemy of the king of the pirates."
#
# "And how is the King of the pirates supposed to act?"
#
# "Because he is a pirate. He is the king of pirates."
#
# "I don't know, but that's all right, I will tell you this. I have never been
# The king of the pirates is an enemy of the king of the pirates."
#
# "And how is the King of the pirates supposed to act?"
#
# "Because he is a pirate. He is the king of pirates."
#
# "I don't know, but that's all right, I will tell you this. I have never been a
# The king of the pirates is an enemy of the king of the pirates."
#
# "And how is the King of the pirates supposed to act?"
#
# "Because he is a pirate. He is the king of pirates."
#
# "I don't know, but that's all right, I will tell you this. I have never been a pirate
# The king of the pirates is an enemy of the king of the pirates."
#
# "And how is the King of the pirates supposed to act?"
#
# "Because he is a pirate. He is the king of pirates."
#
# "I don't know, but that's all right, I will tell you this. I have never been a pirate before
# The king of the pirates is an enemy of the king of the pirates."
#
# "And how is the King of the pirates supposed to act?"
#
# "Because he is a pirate. He is the king of pirates."
#
# "I don't know, but that's all right, I will tell you this. I have never been a pirate before,
# The king of the pirates is an enemy of the king of the pirates."
#
# "And how is the King of the pirates supposed to act?"
#
# "Because he is a pirate. He is the king of pirates."
#
# "I don't know, but that's all right, I will tell you this. I have never been a pirate before, so
# The king of the pirates is an enemy of the king of the pirates."
#
# "And how is the King of the pirates supposed to act?"
#
# "Because he is a pirate. He is the king of pirates."
#
# "I don't know, but that's all right, I will tell you this. I have never been a pirate before, so I
# The king of the pirates is an enemy of the king of the pirates."
#
# "And how is the King of the pirates supposed to act?"
#
# "Because he is a pirate. He is the king of pirates."
#
# "I don't know, but that's all right, I will tell you this. I have never been a pirate before, so I cannot
# The king of the pirates is an enemy of the king of the pirates."
#
# "And how is the King of the pirates supposed to act?"
#
# "Because he is a pirate. He is the king of pirates."
#
# "I don't know, but that's all right, I will tell you this. I have never been a pirate before, so I cannot say
# The king of the pirates is an enemy of the king of the pirates."
#
# "And how is the King of the pirates supposed to act?"
#
# "Because he is a pirate. He is the king of pirates."
#
# "I don't know, but that's all right, I will tell you this. I have never been a pirate before, so I cannot say anything
# The king of the pirates is an enemy of the king of the pirates."
#
# "And how is the King of the pirates supposed to act?"
#
# "Because he is a pirate. He is the king of pirates."
#
# "I don't know, but that's all right, I will tell you this. I have never been a pirate before, so I cannot say anything about
# The king of the pirates is an enemy of the king of the pirates."
#
# "And how is the King of the pirates supposed to act?"
#
# "Because he is a pirate. He is the king of pirates."
#
# "I don't know, but that's all right, I will tell you this. I have never been a pirate before, so I cannot say anything about this

# %% [markdown]
# # Nucleus sampling
#
# Top-K sampling has the disadvantage that sometimes there are only a few plausible next tokens, and sometimes there are a lot.  How do we adapt to this situation?  One way is to sample from a fixed proportion of the probability mass.  That is we order the tokens in terms of probability and cut off the possibility of sampling when the cumulative sum is greater than a threshold.
#
# This way, we adapt the number of possible tokens that we can choose.

# %%
def get_nucleus_sampling_token(input_tokens, model, tokenizer, thresh=0.25):
  # Run model to get prediction over next output
  outputs = model(input_ids = input_tokens['input_ids'], attention_mask = input_tokens['attention_mask'])
  # Find prediction
  prob_over_tokens = F.softmax(outputs.logits, dim=-1).detach().numpy()[0,-1]

  # Find the most likely tokens that make up the first (thresh) of the probability
  # TODO -- sort the probabilities in decreasing order
  # Replace this line
  sorted_probs_decreasing = np.sort(prob_over_tokens)[::-1]

  # TODO -- compute the cumulative sum of these probabilities
  # Replace this line
  cum_sum_probs = np.cumsum(sorted_probs_decreasing)

  # Find index where that the cumulative sum is greater than the threshold
  thresh_index = np.argmax(cum_sum_probs>thresh)

  print("Choosing from %d tokens"%(thresh_index))
  # TODO:  Find the probability value to threshold
  # Replace this line:
  thresh_prob = sorted_probs_decreasing[thresh_index]

  # Set any probabilities less than this to zero
  prob_over_tokens[prob_over_tokens<thresh_prob] = 0
  # Renormalize
  prob_over_tokens = prob_over_tokens / np.sum(prob_over_tokens)
  # Draw random token
  next_token = np.random.choice(len(prob_over_tokens), 1, replace=False, p=prob_over_tokens)

  # Append token to sentence
  output_tokens = input_tokens
  output_tokens["input_ids"] = torch.cat((output_tokens['input_ids'],torch.tensor([next_token])),dim=1)
  output_tokens['attention_mask'] = torch.cat((output_tokens['attention_mask'],torch.tensor([[1]])),dim=1)
  output_tokens['last_token_prob'] = prob_over_tokens[next_token]
  return output_tokens

# %%
# Expected output:
# The best thing about Bath is that it's not a city that has been around
set_seed(0)
input_txt = "The best thing about Bath is"
input_tokens = tokenizer(input_txt, return_tensors='pt')
for i in range(10):
    input_tokens = get_nucleus_sampling_token(input_tokens, model, tokenizer, thresh = 0.2)
    print(tokenizer.decode(input_tokens["input_ids"][0], skip_special_tokens=True))
# Out:
# Choosing from 0 tokens
# The best thing about Bath is that
# Choosing from 0 tokens
# The best thing about Bath is that it
# Choosing from 0 tokens
# The best thing about Bath is that it's
# Choosing from 2 tokens
# The best thing about Bath is that it's not
# Choosing from 1 tokens
# The best thing about Bath is that it's not a
# Choosing from 25 tokens
# The best thing about Bath is that it's not a city
# Choosing from 2 tokens
# The best thing about Bath is that it's not a city that
# Choosing from 1 tokens
# The best thing about Bath is that it's not a city that has
# Choosing from 1 tokens
# The best thing about Bath is that it's not a city that has been
# Choosing from 11 tokens
# The best thing about Bath is that it's not a city that has been around

# %%
# TODO -- experiment with setting the threshold probability to larger or smaller values
input_txt = "The king of the pirates is"
input_tokens = tokenizer(input_txt, return_tensors='pt')
for i in range(60):
    input_tokens = get_nucleus_sampling_token(input_tokens, model, tokenizer, thresh = 0.2)
    print(tokenizer.decode(input_tokens["input_ids"][0], skip_special_tokens=True))
# Out:
# Choosing from 5 tokens
# The king of the pirates is not
# Choosing from 3 tokens
# The king of the pirates is not the
# Choosing from 0 tokens
# The king of the pirates is not the only
# Choosing from 0 tokens
# The king of the pirates is not the only one
# Choosing from 0 tokens
# The king of the pirates is not the only one who
# Choosing from 1 tokens
# The king of the pirates is not the only one who is
# Choosing from 16 tokens
# The king of the pirates is not the only one who is a
# Choosing from 3 tokens
# The king of the pirates is not the only one who is a pirate
# Choosing from 0 tokens
# The king of the pirates is not the only one who is a pirate.
# Choosing from 1 tokens
# The king of the pirates is not the only one who is a pirate. The
# Choosing from 4 tokens
# The king of the pirates is not the only one who is a pirate. The pirates
# Choosing from 0 tokens
# The king of the pirates is not the only one who is a pirate. The pirates are
# Choosing from 0 tokens
# The king of the pirates is not the only one who is a pirate. The pirates are also
# Choosing from 2 tokens
# The king of the pirates is not the only one who is a pirate. The pirates are also known
# Choosing from 0 tokens
# The king of the pirates is not the only one who is a pirate. The pirates are also known as
# Choosing from 0 tokens
# The king of the pirates is not the only one who is a pirate. The pirates are also known as the
# Choosing from 19 tokens
# The king of the pirates is not the only one who is a pirate. The pirates are also known as the "
# Choosing from 26 tokens
# The king of the pirates is not the only one who is a pirate. The pirates are also known as the "Pir
# Choosing from 0 tokens
# The king of the pirates is not the only one who is a pirate. The pirates are also known as the "Pirates
# Choosing from 0 tokens
# The king of the pirates is not the only one who is a pirate. The pirates are also known as the "Pirates of
# Choosing from 0 tokens
# The king of the pirates is not the only one who is a pirate. The pirates are also known as the "Pirates of the
# Choosing from 0 tokens
# The king of the pirates is not the only one who is a pirate. The pirates are also known as the "Pirates of the Caribbean
# Choosing from 0 tokens
# The king of the pirates is not the only one who is a pirate. The pirates are also known as the "Pirates of the Caribbean."
# Choosing from 0 tokens
# The king of the pirates is not the only one who is a pirate. The pirates are also known as the "Pirates of the Caribbean."
#
# Choosing from 0 tokens
# The king of the pirates is not the only one who is a pirate. The pirates are also known as the "Pirates of the Caribbean."
#
#
# Choosing from 1 tokens
# The king of the pirates is not the only one who is a pirate. The pirates are also known as the "Pirates of the Caribbean."
#
# The
# Choosing from 1 tokens
# The king of the pirates is not the only one who is a pirate. The pirates are also known as the "Pirates of the Caribbean."
#
# The pirates
# Choosing from 0 tokens
# The king of the pirates is not the only one who is a pirate. The pirates are also known as the "Pirates of the Caribbean."
#
# The pirates are
# Choosing from 2 tokens
# The king of the pirates is not the only one who is a pirate. The pirates are also known as the "Pirates of the Caribbean."
#
# The pirates are also
# Choosing from 0 tokens
# The king of the pirates is not the only one who is a pirate. The pirates are also known as the "Pirates of the Caribbean."
#
# The pirates are also known
# Choosing from 0 tokens
# The king of the pirates is not the only one who is a pirate. The pirates are also known as the "Pirates of the Caribbean."
#
# The pirates are also known as
# Choosing from 0 tokens
# The king of the pirates is not the only one who is a pirate. The pirates are also known as the "Pirates of the Caribbean."
#
# The pirates are also known as the
# Choosing from 0 tokens
# The king of the pirates is not the only one who is a pirate. The pirates are also known as the "Pirates of the Caribbean."
#
# The pirates are also known as the "
# Choosing from 0 tokens
# The king of the pirates is not the only one who is a pirate. The pirates are also known as the "Pirates of the Caribbean."
#
# The pirates are also known as the "Pir
# Choosing from 0 tokens
# The king of the pirates is not the only one who is a pirate. The pirates are also known as the "Pirates of the Caribbean."
#
# The pirates are also known as the "Pirates
# Choosing from 0 tokens
# The king of the pirates is not the only one who is a pirate. The pirates are also known as the "Pirates of the Caribbean."
#
# The pirates are also known as the "Pirates of
# Choosing from 0 tokens
# The king of the pirates is not the only one who is a pirate. The pirates are also known as the "Pirates of the Caribbean."
#
# The pirates are also known as the "Pirates of the
# Choosing from 0 tokens
# The king of the pirates is not the only one who is a pirate. The pirates are also known as the "Pirates of the Caribbean."
#
# The pirates are also known as the "Pirates of the Caribbean
# Choosing from 0 tokens
# The king of the pirates is not the only one who is a pirate. The pirates are also known as the "Pirates of the Caribbean."
#
# The pirates are also known as the "Pirates of the Caribbean."
# Choosing from 0 tokens
# The king of the pirates is not the only one who is a pirate. The pirates are also known as the "Pirates of the Caribbean."
#
# The pirates are also known as the "Pirates of the Caribbean." The
# Choosing from 1 tokens
# The king of the pirates is not the only one who is a pirate. The pirates are also known as the "Pirates of the Caribbean."
#
# The pirates are also known as the "Pirates of the Caribbean." The pirates
# Choosing from 0 tokens
# The king of the pirates is not the only one who is a pirate. The pirates are also known as the "Pirates of the Caribbean."
#
# The pirates are also known as the "Pirates of the Caribbean." The pirates are
# Choosing from 0 tokens
# The king of the pirates is not the only one who is a pirate. The pirates are also known as the "Pirates of the Caribbean."
#
# The pirates are also known as the "Pirates of the Caribbean." The pirates are also
# Choosing from 0 tokens
# The king of the pirates is not the only one who is a pirate. The pirates are also known as the "Pirates of the Caribbean."
#
# The pirates are also known as the "Pirates of the Caribbean." The pirates are also known
# Choosing from 0 tokens
# The king of the pirates is not the only one who is a pirate. The pirates are also known as the "Pirates of the Caribbean."
#
# The pirates are also known as the "Pirates of the Caribbean." The pirates are also known as
# Choosing from 0 tokens
# The king of the pirates is not the only one who is a pirate. The pirates are also known as the "Pirates of the Caribbean."
#
# The pirates are also known as the "Pirates of the Caribbean." The pirates are also known as the
# Choosing from 0 tokens
# The king of the pirates is not the only one who is a pirate. The pirates are also known as the "Pirates of the Caribbean."
#
# The pirates are also known as the "Pirates of the Caribbean." The pirates are also known as the "
# Choosing from 0 tokens
# The king of the pirates is not the only one who is a pirate. The pirates are also known as the "Pirates of the Caribbean."
#
# The pirates are also known as the "Pirates of the Caribbean." The pirates are also known as the "Pir
# Choosing from 0 tokens
# The king of the pirates is not the only one who is a pirate. The pirates are also known as the "Pirates of the Caribbean."
#
# The pirates are also known as the "Pirates of the Caribbean." The pirates are also known as the "Pirates
# Choosing from 0 tokens
# The king of the pirates is not the only one who is a pirate. The pirates are also known as the "Pirates of the Caribbean."
#
# The pirates are also known as the "Pirates of the Caribbean." The pirates are also known as the "Pirates of
# Choosing from 0 tokens
# The king of the pirates is not the only one who is a pirate. The pirates are also known as the "Pirates of the Caribbean."
#
# The pirates are also known as the "Pirates of the Caribbean." The pirates are also known as the "Pirates of the
# Choosing from 0 tokens
# The king of the pirates is not the only one who is a pirate. The pirates are also known as the "Pirates of the Caribbean."
#
# The pirates are also known as the "Pirates of the Caribbean." The pirates are also known as the "Pirates of the Caribbean
# Choosing from 1 tokens
# The king of the pirates is not the only one who is a pirate. The pirates are also known as the "Pirates of the Caribbean."
#
# The pirates are also known as the "Pirates of the Caribbean." The pirates are also known as the "Pirates of the Caribbean."
# Choosing from 0 tokens
# The king of the pirates is not the only one who is a pirate. The pirates are also known as the "Pirates of the Caribbean."
#
# The pirates are also known as the "Pirates of the Caribbean." The pirates are also known as the "Pirates of the Caribbean." The
# Choosing from 0 tokens
# The king of the pirates is not the only one who is a pirate. The pirates are also known as the "Pirates of the Caribbean."
#
# The pirates are also known as the "Pirates of the Caribbean." The pirates are also known as the "Pirates of the Caribbean." The pirates
# Choosing from 0 tokens
# The king of the pirates is not the only one who is a pirate. The pirates are also known as the "Pirates of the Caribbean."
#
# The pirates are also known as the "Pirates of the Caribbean." The pirates are also known as the "Pirates of the Caribbean." The pirates are
# Choosing from 0 tokens
# The king of the pirates is not the only one who is a pirate. The pirates are also known as the "Pirates of the Caribbean."
#
# The pirates are also known as the "Pirates of the Caribbean." The pirates are also known as the "Pirates of the Caribbean." The pirates are also
# Choosing from 0 tokens
# The king of the pirates is not the only one who is a pirate. The pirates are also known as the "Pirates of the Caribbean."
#
# The pirates are also known as the "Pirates of the Caribbean." The pirates are also known as the "Pirates of the Caribbean." The pirates are also known
# Choosing from 0 tokens
# The king of the pirates is not the only one who is a pirate. The pirates are also known as the "Pirates of the Caribbean."
#
# The pirates are also known as the "Pirates of the Caribbean." The pirates are also known as the "Pirates of the Caribbean." The pirates are also known as
# Choosing from 0 tokens
# The king of the pirates is not the only one who is a pirate. The pirates are also known as the "Pirates of the Caribbean."
#
# The pirates are also known as the "Pirates of the Caribbean." The pirates are also known as the "Pirates of the Caribbean." The pirates are also known as the

# %% [markdown]
# # Beam search
#
# All of the methods we've seen so far choose the tokens one by one.  But this isn't necessarily sensible.  Even greedily choosing the best token doesn't necessarily retrieve the sequence with the highest probability.  It might be that the most likely token only has very unlikely tokens following it.
#
# Beam search maintains $K$ hypotheses about the best possible continuation.  It starts with the top $K$ continuations.  Then for each of those, it finds the top K continuations, giving $K^2$ hypotheses.  Then it retains just the top $K$ of these so that the number of hypotheses stays the same.

# %%
# This routine returns the k'th most likely next token.
# If k =0 then it returns the most likely token, if k=1 it returns the next most likely and so on
# We will need this for beam search
def get_kth_most_likely_token(input_tokens, model, tokenizer, k):
  # Run model to get prediction over next output
  outputs = model(input_ids = input_tokens['input_ids'], attention_mask = input_tokens['attention_mask'])
  # Find prediction
  prob_over_tokens = F.softmax(outputs.logits, dim=-1).detach().numpy()[0,-1]

  # Find the k'th most likely token
  # TODO Sort the probabilities from largest to smallest
  # Replace this line:
  sorted_prob_over_tokens = np.sort(prob_over_tokens)[::-1]
  # TODO Find the k'th sorted probability
  # Replace this line
  kth_prob_value = sorted_prob_over_tokens[k-1]


  # Find position of this token.
  next_token = np.where(prob_over_tokens == kth_prob_value)[0]

  # Append token to sentence
  output_tokens = input_tokens
  output_tokens["input_ids"] = torch.cat((output_tokens['input_ids'],torch.tensor([next_token])),dim=1)
  output_tokens['attention_mask'] = torch.cat((output_tokens['attention_mask'],torch.tensor([[1]])),dim=1)
  output_tokens['last_token_prob'] = prob_over_tokens[next_token]
  output_tokens['log_prob'] = output_tokens['log_prob'] + np.log(prob_over_tokens[next_token])
  return output_tokens

# %%
# We can test this code and see that if we choose the 2nd most likely (K=1) token each time
# then we get much better generation results than if we choose the 2001st most likely token

# Expected output:
# The best thing about Bath is the way you get the most bang outta the
set_seed(0)
input_txt = "The best thing about Bath is"
input_tokens = tokenizer(input_txt, return_tensors='pt')
input_tokens['log_prob'] = 0.0
for i in range(10):
    input_tokens = get_kth_most_likely_token(input_tokens, model, tokenizer, k=1)
    print(tokenizer.decode(input_tokens["input_ids"][0], skip_special_tokens=True))

# Expected output:
# The best thing about Bath is mixed profits partnerships» buy generic+ Honda throttlecont
input_txt = "The best thing about Bath is"
input_tokens = tokenizer(input_txt, return_tensors='pt')
input_tokens['log_prob'] = 0.0
for i in range(10):
    input_tokens = get_kth_most_likely_token(input_tokens, model, tokenizer, k=2000)
    print(tokenizer.decode(input_tokens["input_ids"][0], skip_special_tokens=True))

# TODO -- play around with different values of K
# Out:
# The best thing about Bath is that
# The best thing about Bath is that it
# The best thing about Bath is that it's
# The best thing about Bath is that it's a
# The best thing about Bath is that it's a place
# The best thing about Bath is that it's a place where
# The best thing about Bath is that it's a place where you
# The best thing about Bath is that it's a place where you can
# The best thing about Bath is that it's a place where you can go
# The best thing about Bath is that it's a place where you can go to
# The best thing about Bath is res
# The best thing about Bath is res compound
# The best thing about Bath is res compound bonus
# The best thing about Bath is res compound bonus nonsense
# The best thing about Bath is res compound bonus nonsensewhich
# The best thing about Bath is res compound bonus nonsensewhich cap
# The best thing about Bath is res compound bonus nonsensewhich cap native
# The best thing about Bath is res compound bonus nonsensewhich cap native mutation
# The best thing about Bath is res compound bonus nonsensewhich cap native mutation precision
# The best thing about Bath is res compound bonus nonsensewhich cap native mutation precision 260

# %%
# Print out each beam plus the log probability
def print_beams(beams):
  for index,beam in enumerate(beams):
    print("Beam %d, Prob %3.3f: "%(index,beam['log_prob'])+tokenizer.decode(beam["input_ids"][0], skip_special_tokens=True))
  print('---')


# TODO:  Read this code carefully!
def do_beam_search(input_tokens_in, model, tokenizer, n_beam=5, beam_length=10):
  # Store beams in a list
  input_tokens['log_prob'] = 0.0

  # Initialize with n_beam most likely continuations
  beams = [None] * n_beam
  for c_k in range(n_beam):
    beams[c_k] = dict(input_tokens_in)
    beams[c_k] = get_kth_most_likely_token(beams[c_k], model, tokenizer, c_k)

  print_beams(beams)

  # For each token in the sequence we will add
  for c_pos in range(beam_length-1):
    # Now for each beam, we continue it in the most likely ways, making n_beam*n_beam type hypotheses
    beams_all = [None] * (n_beam*n_beam)
    log_probs_all = np.zeros(n_beam*n_beam)
    # For each current hypothesis
    for c_beam in range(n_beam):
      # For each continuation
      for c_k in range(n_beam):
        # Store the continuation and the probability
        beams_all[c_beam * n_beam + c_k] = dict(get_kth_most_likely_token(beams[c_beam], model, tokenizer, c_k))
        log_probs_all[c_beam * n_beam + c_k] = beams_all[c_beam * n_beam + c_k]['log_prob']

    # Keep the best n_beams sequences with the highest probabilities
    sorted_index = np.argsort(np.array(log_probs_all)*-1)
    for c_k in range(n_beam):
      beams[c_k] = dict(beams_all[sorted_index[c_k]])

    # Print the beams
    print_beams(beams)

  return beams[0]

# %%
# Expected output:
# The best thing about Bath is that it's a place where you don't have to

set_seed(0)
input_txt = "The best thing about Bath is"
input_tokens = tokenizer(input_txt, return_tensors='pt')

# Now let's call the beam search
# It takes a while as it has to run the model multiple times to add a token
n_beams = 5
best_beam = do_beam_search(input_tokens,model,tokenizer)
print("Beam search result:")
print(tokenizer.decode(best_beam["input_ids"][0], skip_special_tokens=True))

# You should see that the best answer is not the same as the greedy solution we found above
# Out:
# /tmp/ipython-input-4010751250.py:4: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Beam %d, Prob %3.3f: "%(index,beam['log_prob'])+tokenizer.decode(beam["input_ids"][0], skip_special_tokens=True))
# /tmp/ipython-input-4010751250.py:32: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   log_probs_all[c_beam * n_beam + c_k] = beams_all[c_beam * n_beam + c_k]['log_prob']
# Beam 0, Prob -30.111: The best thing about Bath is��士
# Beam 1, Prob -0.727: The best thing about Bath is that
# Beam 2, Prob -2.161: The best thing about Bath is the
# Beam 3, Prob -3.177: The best thing about Bath is it
# Beam 4, Prob -3.468: The best thing about Bath is how
# ---
# Beam 0, Prob -31.179: The best thing about Bath is theInstoreAndOnline
# Beam 1, Prob -34.496: The best thing about Bath is theInstoreAndOnline.
# Beam 2, Prob -35.333: The best thing about Bath is that pione
# Beam 3, Prob -35.921: The best thing about Bath is that pioneering
# Beam 4, Prob -36.707: The best thing about Bath is howEStream
# ---
# Beam 0, Prob -53.321: The best thing about Bath is theInstoreAndOnline��
# Beam 1, Prob -56.374: The best thing about Bath is theInstoreAndOnline��.
# Beam 2, Prob -58.927: The best thing about Bath is theInstoreAndOnline��.
#
# Beam 3, Prob -63.282: The best thing about Bath is that pione覚醒
# Beam 4, Prob -64.163: The best thing about Bath is theInstoreAndOnline��.
# I
# ---
# Beam 0, Prob -74.587: The best thing about Bath is theInstoreAndOnline��ertodd
# Beam 1, Prob -77.164: The best thing about Bath is theInstoreAndOnline��ertodd.
# Beam 2, Prob -80.025: The best thing about Bath is theInstoreAndOnline��ertodd. It
# Beam 3, Prob -82.179: The best thing about Bath is theInstoreAndOnline��. millenn
# Beam 4, Prob -83.021: The best thing about Bath is theInstoreAndOnline��ertodd. It has
# ---
# Beam 0, Prob -98.467: The best thing about Bath is theInstoreAndOnline��ertoddBuyableInstoreAndOnline
# Beam 1, Prob -101.914: The best thing about Bath is theInstoreAndOnline��ertoddBuyableInstoreAndOnline.
# Beam 2, Prob -102.001: The best thing about Bath is theInstoreAndOnline��ertodd.��
# Beam 3, Prob -103.825: The best thing about Bath is theInstoreAndOnline��ertodd.��.
# Beam 4, Prob -104.395: The best thing about Bath is theInstoreAndOnline��ertoddBuyableInstoreAndOnline.
#
# ---
# Beam 0, Prob -124.051: The best thing about Bath is theInstoreAndOnline��ertoddBuyableInstoreAndOnline��
# Beam 1, Prob -124.484: The best thing about Bath is theInstoreAndOnline��ertodd.��ierrez
# Beam 2, Prob -125.952: The best thing about Bath is theInstoreAndOnline��ertodd.��ierrez.
# Beam 3, Prob -127.046: The best thing about Bath is theInstoreAndOnline��ertodd.��. volunte
# Beam 4, Prob -127.268: The best thing about Bath is theInstoreAndOnline��ertoddBuyableInstoreAndOnline. millenn
# ---
# Beam 0, Prob -145.392: The best thing about Bath is theInstoreAndOnline��ertoddBuyableInstoreAndOnline�� srf
# Beam 1, Prob -146.289: The best thing about Bath is theInstoreAndOnline��ertodd.��ierrez earthqu
# Beam 2, Prob -148.678: The best thing about Bath is theInstoreAndOnline��ertodd.��ierrez. exting
# Beam 3, Prob -148.843: The best thing about Bath is theInstoreAndOnline��ertoddBuyableInstoreAndOnline�� srf.
# Beam 4, Prob -149.707: The best thing about Bath is theInstoreAndOnline��ertodd.��ierrez earthquak
# ---
# Beam 0, Prob -165.314: The best thing about Bath is theInstoreAndOnline��ertoddBuyableInstoreAndOnline�� srf Leban
# Beam 1, Prob -166.197: The best thing about Bath is theInstoreAndOnline��ertodd.��ierrez earthquBuyableInstoreAndOnline
# Beam 2, Prob -169.183: The best thing about Bath is theInstoreAndOnline��ertodd.��ierrez. extingBuyableInstoreAndOnline
# Beam 3, Prob -169.213: The best thing about Bath is theInstoreAndOnline��ertoddBuyableInstoreAndOnline�� srf Leban
#
# Beam 4, Prob -169.293: The best thing about Bath is theInstoreAndOnline��ertodd.��ierrez earthquBuyableInstoreAndOnline.
# ---
# Beam 0, Prob -184.427: The best thing about Bath is theInstoreAndOnline��ertoddBuyableInstoreAndOnline�� srf Leban��
# Beam 1, Prob -187.764: The best thing about Bath is theInstoreAndOnline��ertodd.��ierrez earthquBuyableInstoreAndOnline��
# Beam 2, Prob -188.443: The best thing about Bath is theInstoreAndOnline��ertoddBuyableInstoreAndOnline�� srf Leban��J
# Beam 3, Prob -189.374: The best thing about Bath is theInstoreAndOnline��ertodd.��ierrez earthquBuyableInstoreAndOnline. antidepress
# Beam 4, Prob -190.220: The best thing about Bath is theInstoreAndOnline��ertodd.��ierrez earthquBuyableInstoreAndOnline��.
# ---
# Beam 0, Prob -204.288: The best thing about Bath is theInstoreAndOnline��ertoddBuyableInstoreAndOnline�� srf Leban�� loopholes
# Beam 1, Prob -207.619: The best thing about Bath is theInstoreAndOnline��ertoddBuyableInstoreAndOnline�� srf Leban�� loopholes.
# Beam 2, Prob -207.966: The best thing about Bath is theInstoreAndOnline��ertoddBuyableInstoreAndOnline�� srf Leban��Jciation
# Beam 3, Prob -208.182: The best thing about Bath is theInstoreAndOnline��ertodd.��ierrez earthquBuyableInstoreAndOnline. antidepressSPONSORED
# Beam 4, Prob -208.680: The best thing about Bath is theInstoreAndOnline��ertodd.��ierrez earthquBuyableInstoreAndOnline�� antidepress
# ---
# Beam search result:
# The best thing about Bath is theInstoreAndOnline��ertoddBuyableInstoreAndOnline�� srf Leban�� loopholes

# %% [markdown]
# You can read about more decoding strategies in this blog (which uses a recursive neural network, not a transformer, but the principles are the same).
#
# https://www.borealisai.com/research-blogs/tutorial-6-neural-natural-language-generation-decoding-algorithms/
#
# You can also look at other possible language models via hugging face:
#
# https://huggingface.co/docs/transformers/v4.25.1/en/model_summary#decoders-or-autoregressive-models
